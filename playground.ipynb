# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)

df = pd.read_csv("./new_preprocessed_final.csv")
df.sample(n=5, random_state=42)
# Out:
#       __row_id__  \
# 1801        1801
# 1190        1190
# 1817        1817
# 251          251
# 2505        2505
#
#                                                                     title_clean_sim  \
# 1801             tp pkk kabupaten bogor gelar pengajian, tingkatkan nilai keagamaan
# 1190       situasi terkini demo di dpr: massa masuk tol dalam kota-barrier terbakar
# 1817               merek mobil indonesia aletra hadir di giias 2025, bawa model ini
# 251   mulai besok ada pengalihan lalu lintas di jakarta, catat jadwal dan lokasinya
# 2505                                    cara perpanjang stnk tanpa ktp pemilik lama
#
#       cosine_similarity  token_overlap  bert_similarity  title_length  \
# 1801           0.674938       0.888889         0.513425             9
# 1190           0.537536       0.700000         0.564060            12
# 1817           0.636532       0.888889         0.567764            11
# 251            0.184160       0.666667         0.402059            12
# 2505           0.558721       0.833333         0.520803             7
#
#       sensational_word_count  punctuation_count  punctuation_ratio  \
# 1801                       4                  0           0.000000
# 1190                       6                  1           0.013889
# 1817                       6                  0           0.000000
# 251                        7                  0           0.000000
# 2505                       3                  0           0.000000
#
#       is_clickbait_auto  is_clickbait_bert
# 1801                  0                  0
# 1190                  0                  0
# 1817                  0                  0
# 251                   1                  1
# 2505                  0                  0
